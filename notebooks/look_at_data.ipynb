# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio
import pandas as pd
import seaborn as sns
import utils

# %%
df = utils.read_toy_data()
df.head()
# Out:
#           x         y class
# 0 -1.959897  0.498693  Case
# 1 -3.346470 -1.843321  Case
# 2 -2.916821 -0.392444  Case
# 3 -3.798834 -1.905248  Case
# 4 -0.466026  0.972492  Case

# %%
df.describe().T
# Out:
#    count      mean       std       min       25%       50%       75%       max
# x  400.0 -0.005533  1.902954 -4.588425 -1.429157 -0.026693  1.274514  5.756113
# y  400.0 -0.021714  1.820031 -6.288145 -1.173108 -0.087950  1.141793  6.106396

# %%
sns.relplot(data = df, x = 'x', y = 'y', hue= 'class')

# %%
sns.relplot(data = df, x = 'x', y = 'y', hue= 'class').savefig('../media/scattered_data.jpeg')
